# %%
# !pip install dask[complete]
# Out:
# Requirement already satisfied: dask[complete] in c:\users\123sa\anaconda3\lib\site-packages (2023.4.1)
# Requirement already satisfied: click>=8.0 in c:\users\123sa\anaconda3\lib\site-packages (from dask[complete]) (8.0.4)
# Requirement already satisfied: cloudpickle>=1.5.0 in c:\users\123sa\anaconda3\lib\site-packages (from dask[complete]) (2.0.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\123sa\anaconda3\lib\site-packages (from dask[complete]) (22.0)
# Requirement already satisfied: importlib-metadata>=4.13.0 in c:\users\123sa\anaconda3\lib\site-packages (from dask[complete]) (6.6.0)
# Requirement already satisfied: partd>=1.2.0 in c:\users\123sa\anaconda3\lib\site-packages (from dask[complete]) (1.2.0)
# Requirement already satisfied: toolz>=0.10.0 in c:\users\123sa\anaconda3\lib\site-packages (from dask[complete]) (0.12.0)
# Requirement already satisfied: fsspec>=2021.09.0 in c:\users\123sa\anaconda3\lib\site-packages (from dask[complete]) (2022.11.0)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\123sa\anaconda3\lib\site-packages (from dask[complete]) (6.0)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\123sa\anaconda3\lib\site-packages (from dask[complete]) (12.0.0)
# Requirement already satisfied: lz4>=4.3.2 in c:\users\123sa\anaconda3\lib\site-packages (from dask[complete]) (4.3.2)
# Requirement already satisfied: colorama in c:\users\123sa\anaconda3\lib\site-packages (from click>=8.0->dask[complete]) (0.4.6)
# Requirement already satisfied: zipp>=0.5 in c:\users\123sa\anaconda3\lib\site-packages (from importlib-metadata>=4.13.0->dask[complete]) (3.11.0)
# Requirement already satisfied: locket in c:\users\123sa\anaconda3\lib\site-packages (from partd>=1.2.0->dask[complete]) (1.0.0)
# Requirement already satisfied: numpy>=1.16.6 in c:\users\123sa\anaconda3\lib\site-packages (from pyarrow>=7.0->dask[complete]) (1.23.5)
# Requirement already satisfied: distributed==2023.4.1 in c:\users\123sa\anaconda3\lib\site-packages (from dask[complete]) (2023.4.1)
# Requirement already satisfied: pandas>=1.3 in c:\users\123sa\anaconda3\lib\site-packages (from dask[complete]) (1.5.3)
# Requirement already satisfied: bokeh>=2.4.2 in c:\users\123sa\anaconda3\lib\site-packages (from dask[complete]) (2.4.3)
# Requirement already satisfied: jinja2>=2.10.3 in c:\users\123sa\anaconda3\lib\site-packages (from dask[complete]) (3.1.2)
# Requirement already satisfied: psutil>=5.7.0 in c:\users\123sa\anaconda3\lib\site-packages (from distributed==2023.4.1->dask[complete]) (5.9.0)
# Requirement already satisfied: tornado>=6.0.3 in c:\users\123sa\anaconda3\lib\site-packages (from distributed==2023.4.1->dask[complete]) (6.1)
# Requirement already satisfied: sortedcontainers>=2.0.5 in c:\users\123sa\anaconda3\lib\site-packages (from distributed==2023.4.1->dask[complete]) (2.4.0)
# Requirement already satisfied: urllib3>=1.24.3 in c:\users\123sa\anaconda3\lib\site-packages (from distributed==2023.4.1->dask[complete]) (1.26.14)
# Requirement already satisfied: zict>=2.2.0 in c:\users\123sa\anaconda3\lib\site-packages (from distributed==2023.4.1->dask[complete]) (3.0.0)
# Requirement already satisfied: msgpack>=1.0.0 in c:\users\123sa\anaconda3\lib\site-packages (from distributed==2023.4.1->dask[complete]) (1.0.3)
# Requirement already satisfied: tblib>=1.6.0 in c:\users\123sa\anaconda3\lib\site-packages (from distributed==2023.4.1->dask[complete]) (1.7.0)
# Requirement already satisfied: pillow>=7.1.0 in c:\users\123sa\anaconda3\lib\site-packages (from bokeh>=2.4.2->dask[complete]) (9.4.0)
# Requirement already satisfied: typing-extensions>=3.10.0 in c:\users\123sa\anaconda3\lib\site-packages (from bokeh>=2.4.2->dask[complete]) (4.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\123sa\anaconda3\lib\site-packages (from jinja2>=2.10.3->dask[complete]) (2.1.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\123sa\anaconda3\lib\site-packages (from pandas>=1.3->dask[complete]) (2022.7)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\123sa\anaconda3\lib\site-packages (from pandas>=1.3->dask[complete]) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\123sa\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas>=1.3->dask[complete]) (1.16.0)

# %%
# !pip install dask distributed --upgrade
# !pip install dask
# !pip install cloudpickle
# !pip install "dask[dataframe]"
# !pip install "dask[complete]"
# Out:
# Requirement already satisfied: dask in c:\users\123sa\anaconda3\lib\site-packages (2023.4.1)
# Requirement already satisfied: distributed in c:\users\123sa\anaconda3\lib\site-packages (2023.4.1)
# Requirement already satisfied: importlib-metadata>=4.13.0 in c:\users\123sa\anaconda3\lib\site-packages (from dask) (6.6.0)
# Requirement already satisfied: fsspec>=2021.09.0 in c:\users\123sa\anaconda3\lib\site-packages (from dask) (2022.11.0)
# Requirement already satisfied: toolz>=0.10.0 in c:\users\123sa\anaconda3\lib\site-packages (from dask) (0.12.0)
# Requirement already satisfied: partd>=1.2.0 in c:\users\123sa\anaconda3\lib\site-packages (from dask) (1.2.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\123sa\anaconda3\lib\site-packages (from dask) (22.0)
# Requirement already satisfied: click>=8.0 in c:\users\123sa\anaconda3\lib\site-packages (from dask) (8.0.4)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\123sa\anaconda3\lib\site-packages (from dask) (6.0)
# Requirement already satisfied: cloudpickle>=1.5.0 in c:\users\123sa\anaconda3\lib\site-packages (from dask) (2.0.0)
# Requirement already satisfied: sortedcontainers>=2.0.5 in c:\users\123sa\anaconda3\lib\site-packages (from distributed) (2.4.0)
# Requirement already satisfied: tblib>=1.6.0 in c:\users\123sa\anaconda3\lib\site-packages (from distributed) (1.7.0)
# Requirement already satisfied: tornado>=6.0.3 in c:\users\123sa\anaconda3\lib\site-packages (from distributed) (6.1)
# Requirement already satisfied: msgpack>=1.0.0 in c:\users\123sa\anaconda3\lib\site-packages (from distributed) (1.0.3)
# Requirement already satisfied: jinja2>=2.10.3 in c:\users\123sa\anaconda3\lib\site-packages (from distributed) (3.1.2)
# Requirement already satisfied: urllib3>=1.24.3 in c:\users\123sa\anaconda3\lib\site-packages (from distributed) (1.26.14)
# Requirement already satisfied: zict>=2.2.0 in c:\users\123sa\anaconda3\lib\site-packages (from distributed) (3.0.0)
# Requirement already satisfied: locket>=1.0.0 in c:\users\123sa\anaconda3\lib\site-packages (from distributed) (1.0.0)
# Requirement already satisfied: psutil>=5.7.0 in c:\users\123sa\anaconda3\lib\site-packages (from distributed) (5.9.0)
# Requirement already satisfied: colorama in c:\users\123sa\anaconda3\lib\site-packages (from click>=8.0->dask) (0.4.6)
# Requirement already satisfied: zipp>=0.5 in c:\users\123sa\anaconda3\lib\site-packages (from importlib-metadata>=4.13.0->dask) (3.11.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\123sa\anaconda3\lib\site-packages (from jinja2>=2.10.3->distributed) (2.1.1)
# Requirement already satisfied: dask in c:\users\123sa\anaconda3\lib\site-packages (2023.4.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\123sa\anaconda3\lib\site-packages (from dask) (22.0)
# Requirement already satisfied: cloudpickle>=1.5.0 in c:\users\123sa\anaconda3\lib\site-packages (from dask) (2.0.0)
# Requirement already satisfied: fsspec>=2021.09.0 in c:\users\123sa\anaconda3\lib\site-packages (from dask) (2022.11.0)
# Requirement already satisfied: toolz>=0.10.0 in c:\users\123sa\anaconda3\lib\site-packages (from dask) (0.12.0)
# Requirement already satisfied: importlib-metadata>=4.13.0 in c:\users\123sa\anaconda3\lib\site-packages (from dask) (6.6.0)
# Requirement already satisfied: click>=8.0 in c:\users\123sa\anaconda3\lib\site-packages (from dask) (8.0.4)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\123sa\anaconda3\lib\site-packages (from dask) (6.0)
# Requirement already satisfied: partd>=1.2.0 in c:\users\123sa\anaconda3\lib\site-packages (from dask) (1.2.0)
# Requirement already satisfied: colorama in c:\users\123sa\anaconda3\lib\site-packages (from click>=8.0->dask) (0.4.6)
# Requirement already satisfied: zipp>=0.5 in c:\users\123sa\anaconda3\lib\site-packages (from importlib-metadata>=4.13.0->dask) (3.11.0)
# Requirement already satisfied: locket in c:\users\123sa\anaconda3\lib\site-packages (from partd>=1.2.0->dask) (1.0.0)
# Requirement already satisfied: cloudpickle in c:\users\123sa\anaconda3\lib\site-packages (2.0.0)
# Requirement already satisfied: dask[dataframe] in c:\users\123sa\anaconda3\lib\site-packages (2023.4.1)
# Requirement already satisfied: fsspec>=2021.09.0 in c:\users\123sa\anaconda3\lib\site-packages (from dask[dataframe]) (2022.11.0)
# Requirement already satisfied: click>=8.0 in c:\users\123sa\anaconda3\lib\site-packages (from dask[dataframe]) (8.0.4)
# Requirement already satisfied: partd>=1.2.0 in c:\users\123sa\anaconda3\lib\site-packages (from dask[dataframe]) (1.2.0)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\123sa\anaconda3\lib\site-packages (from dask[dataframe]) (6.0)
# Requirement already satisfied: importlib-metadata>=4.13.0 in c:\users\123sa\anaconda3\lib\site-packages (from dask[dataframe]) (6.6.0)
# Requirement already satisfied: cloudpickle>=1.5.0 in c:\users\123sa\anaconda3\lib\site-packages (from dask[dataframe]) (2.0.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\123sa\anaconda3\lib\site-packages (from dask[dataframe]) (22.0)
# Requirement already satisfied: toolz>=0.10.0 in c:\users\123sa\anaconda3\lib\site-packages (from dask[dataframe]) (0.12.0)
# Requirement already satisfied: pandas>=1.3 in c:\users\123sa\anaconda3\lib\site-packages (from dask[dataframe]) (1.5.3)
# Requirement already satisfied: numpy>=1.21 in c:\users\123sa\anaconda3\lib\site-packages (from dask[dataframe]) (1.23.5)
# Requirement already satisfied: colorama in c:\users\123sa\anaconda3\lib\site-packages (from click>=8.0->dask[dataframe]) (0.4.6)
# Requirement already satisfied: zipp>=0.5 in c:\users\123sa\anaconda3\lib\site-packages (from importlib-metadata>=4.13.0->dask[dataframe]) (3.11.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\123sa\anaconda3\lib\site-packages (from pandas>=1.3->dask[dataframe]) (2022.7)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\123sa\anaconda3\lib\site-packages (from pandas>=1.3->dask[dataframe]) (2.8.2)
# Requirement already satisfied: locket in c:\users\123sa\anaconda3\lib\site-packages (from partd>=1.2.0->dask[dataframe]) (1.0.0)
# Requirement already satisfied: six>=1.5 in c:\users\123sa\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas>=1.3->dask[dataframe]) (1.16.0)
# Requirement already satisfied: dask[complete] in c:\users\123sa\anaconda3\lib\site-packages (2023.4.1)
# Requirement already satisfied: partd>=1.2.0 in c:\users\123sa\anaconda3\lib\site-packages (from dask[complete]) (1.2.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\123sa\anaconda3\lib\site-packages (from dask[complete]) (22.0)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\123sa\anaconda3\lib\site-packages (from dask[complete]) (6.0)
# Requirement already satisfied: toolz>=0.10.0 in c:\users\123sa\anaconda3\lib\site-packages (from dask[complete]) (0.12.0)
# Requirement already satisfied: importlib-metadata>=4.13.0 in c:\users\123sa\anaconda3\lib\site-packages (from dask[complete]) (6.6.0)
# Requirement already satisfied: click>=8.0 in c:\users\123sa\anaconda3\lib\site-packages (from dask[complete]) (8.0.4)
# Requirement already satisfied: cloudpickle>=1.5.0 in c:\users\123sa\anaconda3\lib\site-packages (from dask[complete]) (2.0.0)
# Requirement already satisfied: fsspec>=2021.09.0 in c:\users\123sa\anaconda3\lib\site-packages (from dask[complete]) (2022.11.0)
# Requirement already satisfied: lz4>=4.3.2 in c:\users\123sa\anaconda3\lib\site-packages (from dask[complete]) (4.3.2)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\123sa\anaconda3\lib\site-packages (from dask[complete]) (12.0.0)
# Requirement already satisfied: colorama in c:\users\123sa\anaconda3\lib\site-packages (from click>=8.0->dask[complete]) (0.4.6)
# Requirement already satisfied: zipp>=0.5 in c:\users\123sa\anaconda3\lib\site-packages (from importlib-metadata>=4.13.0->dask[complete]) (3.11.0)
# Requirement already satisfied: locket in c:\users\123sa\anaconda3\lib\site-packages (from partd>=1.2.0->dask[complete]) (1.0.0)
# Requirement already satisfied: numpy>=1.16.6 in c:\users\123sa\anaconda3\lib\site-packages (from pyarrow>=7.0->dask[complete]) (1.23.5)
# Requirement already satisfied: pandas>=1.3 in c:\users\123sa\anaconda3\lib\site-packages (from dask[complete]) (1.5.3)
# Requirement already satisfied: distributed==2023.4.1 in c:\users\123sa\anaconda3\lib\site-packages (from dask[complete]) (2023.4.1)
# Requirement already satisfied: bokeh>=2.4.2 in c:\users\123sa\anaconda3\lib\site-packages (from dask[complete]) (2.4.3)
# Requirement already satisfied: jinja2>=2.10.3 in c:\users\123sa\anaconda3\lib\site-packages (from dask[complete]) (3.1.2)
# Requirement already satisfied: psutil>=5.7.0 in c:\users\123sa\anaconda3\lib\site-packages (from distributed==2023.4.1->dask[complete]) (5.9.0)
# Requirement already satisfied: tblib>=1.6.0 in c:\users\123sa\anaconda3\lib\site-packages (from distributed==2023.4.1->dask[complete]) (1.7.0)
# Requirement already satisfied: tornado>=6.0.3 in c:\users\123sa\anaconda3\lib\site-packages (from distributed==2023.4.1->dask[complete]) (6.1)
# Requirement already satisfied: urllib3>=1.24.3 in c:\users\123sa\anaconda3\lib\site-packages (from distributed==2023.4.1->dask[complete]) (1.26.14)
# Requirement already satisfied: msgpack>=1.0.0 in c:\users\123sa\anaconda3\lib\site-packages (from distributed==2023.4.1->dask[complete]) (1.0.3)
# Requirement already satisfied: sortedcontainers>=2.0.5 in c:\users\123sa\anaconda3\lib\site-packages (from distributed==2023.4.1->dask[complete]) (2.4.0)
# Requirement already satisfied: zict>=2.2.0 in c:\users\123sa\anaconda3\lib\site-packages (from distributed==2023.4.1->dask[complete]) (3.0.0)
# Requirement already satisfied: typing-extensions>=3.10.0 in c:\users\123sa\anaconda3\lib\site-packages (from bokeh>=2.4.2->dask[complete]) (4.4.0)
# Requirement already satisfied: pillow>=7.1.0 in c:\users\123sa\anaconda3\lib\site-packages (from bokeh>=2.4.2->dask[complete]) (9.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\123sa\anaconda3\lib\site-packages (from jinja2>=2.10.3->dask[complete]) (2.1.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\123sa\anaconda3\lib\site-packages (from pandas>=1.3->dask[complete]) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\123sa\anaconda3\lib\site-packages (from pandas>=1.3->dask[complete]) (2022.7)
# Requirement already satisfied: six>=1.5 in c:\users\123sa\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas>=1.3->dask[complete]) (1.16.0)

# %%
# !pip install dask_ml
# Out:
# Requirement already satisfied: dask_ml in c:\users\123sa\anaconda3\lib\site-packages (2023.3.24)
# Requirement already satisfied: pandas>=0.24.2 in c:\users\123sa\anaconda3\lib\site-packages (from dask_ml) (1.5.3)
# Requirement already satisfied: numba>=0.51.0 in c:\users\123sa\anaconda3\lib\site-packages (from dask_ml) (0.56.4)
# Requirement already satisfied: numpy>=1.20.0 in c:\users\123sa\anaconda3\lib\site-packages (from dask_ml) (1.23.5)
# Requirement already satisfied: scipy in c:\users\123sa\anaconda3\lib\site-packages (from dask_ml) (1.10.0)
# Requirement already satisfied: multipledispatch>=0.4.9 in c:\users\123sa\anaconda3\lib\site-packages (from dask_ml) (0.6.0)
# Requirement already satisfied: distributed>=2.4.0 in c:\users\123sa\anaconda3\lib\site-packages (from dask_ml) (2023.4.1)
# Requirement already satisfied: dask[array,dataframe]>=2.4.0 in c:\users\123sa\anaconda3\lib\site-packages (from dask_ml) (2023.4.1)
# Requirement already satisfied: packaging in c:\users\123sa\anaconda3\lib\site-packages (from dask_ml) (22.0)
# Requirement already satisfied: scikit-learn>=1.2.0 in c:\users\123sa\anaconda3\lib\site-packages (from dask_ml) (1.2.1)
# Requirement already satisfied: dask-glm>=0.2.0 in c:\users\123sa\anaconda3\lib\site-packages (from dask_ml) (0.2.0)
# Requirement already satisfied: cloudpickle>=0.2.2 in c:\users\123sa\anaconda3\lib\site-packages (from dask-glm>=0.2.0->dask_ml) (2.0.0)
# Requirement already satisfied: importlib-metadata>=4.13.0 in c:\users\123sa\anaconda3\lib\site-packages (from dask[array,dataframe]>=2.4.0->dask_ml) (6.6.0)
# Requirement already satisfied: toolz>=0.10.0 in c:\users\123sa\anaconda3\lib\site-packages (from dask[array,dataframe]>=2.4.0->dask_ml) (0.12.0)
# Requirement already satisfied: partd>=1.2.0 in c:\users\123sa\anaconda3\lib\site-packages (from dask[array,dataframe]>=2.4.0->dask_ml) (1.2.0)
# Requirement already satisfied: click>=8.0 in c:\users\123sa\anaconda3\lib\site-packages (from dask[array,dataframe]>=2.4.0->dask_ml) (8.0.4)
# Requirement already satisfied: fsspec>=2021.09.0 in c:\users\123sa\anaconda3\lib\site-packages (from dask[array,dataframe]>=2.4.0->dask_ml) (2022.11.0)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\123sa\anaconda3\lib\site-packages (from dask[array,dataframe]>=2.4.0->dask_ml) (6.0)
# Requirement already satisfied: tblib>=1.6.0 in c:\users\123sa\anaconda3\lib\site-packages (from distributed>=2.4.0->dask_ml) (1.7.0)
# Requirement already satisfied: jinja2>=2.10.3 in c:\users\123sa\anaconda3\lib\site-packages (from distributed>=2.4.0->dask_ml) (3.1.2)
# Requirement already satisfied: urllib3>=1.24.3 in c:\users\123sa\anaconda3\lib\site-packages (from distributed>=2.4.0->dask_ml) (1.26.14)
# Requirement already satisfied: sortedcontainers>=2.0.5 in c:\users\123sa\anaconda3\lib\site-packages (from distributed>=2.4.0->dask_ml) (2.4.0)
# Requirement already satisfied: locket>=1.0.0 in c:\users\123sa\anaconda3\lib\site-packages (from distributed>=2.4.0->dask_ml) (1.0.0)
# Requirement already satisfied: zict>=2.2.0 in c:\users\123sa\anaconda3\lib\site-packages (from distributed>=2.4.0->dask_ml) (3.0.0)
# Requirement already satisfied: psutil>=5.7.0 in c:\users\123sa\anaconda3\lib\site-packages (from distributed>=2.4.0->dask_ml) (5.9.0)
# Requirement already satisfied: tornado>=6.0.3 in c:\users\123sa\anaconda3\lib\site-packages (from distributed>=2.4.0->dask_ml) (6.1)
# Requirement already satisfied: msgpack>=1.0.0 in c:\users\123sa\anaconda3\lib\site-packages (from distributed>=2.4.0->dask_ml) (1.0.3)
# Requirement already satisfied: six in c:\users\123sa\anaconda3\lib\site-packages (from multipledispatch>=0.4.9->dask_ml) (1.16.0)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in c:\users\123sa\anaconda3\lib\site-packages (from numba>=0.51.0->dask_ml) (0.39.1)
# Requirement already satisfied: setuptools in c:\users\123sa\anaconda3\lib\site-packages (from numba>=0.51.0->dask_ml) (65.6.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\123sa\anaconda3\lib\site-packages (from pandas>=0.24.2->dask_ml) (2022.7)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\123sa\anaconda3\lib\site-packages (from pandas>=0.24.2->dask_ml) (2.8.2)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\123sa\anaconda3\lib\site-packages (from scikit-learn>=1.2.0->dask_ml) (1.1.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\123sa\anaconda3\lib\site-packages (from scikit-learn>=1.2.0->dask_ml) (2.2.0)
# Requirement already satisfied: colorama in c:\users\123sa\anaconda3\lib\site-packages (from click>=8.0->dask[array,dataframe]>=2.4.0->dask_ml) (0.4.6)
# Requirement already satisfied: zipp>=0.5 in c:\users\123sa\anaconda3\lib\site-packages (from importlib-metadata>=4.13.0->dask[array,dataframe]>=2.4.0->dask_ml) (3.11.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\123sa\anaconda3\lib\site-packages (from jinja2>=2.10.3->distributed>=2.4.0->dask_ml) (2.1.1)

# %%
import dask.dataframe as dd
import os
import json
import math
import dask
from dask.distributed import Client
import dask.dataframe as dd
import numpy as np
import dask.multiprocessing

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '.mrx-link-config.yaml',
#  '.mrx-link-logs',
#  '.vscode',
#  'daskproj.ipynb',
#  'daskproj1.ipynb',
#  'flights-larger.csv',
#  'merged.csv',
#  'venv']

# %%
client = Client(n_workers=3, threads_per_worker=1, processes=False)

# %%
client
# Out:
# <Client: 'inproc://192.168.0.100/1940/1' processes=3 threads=3, memory=7.70 GiB>

# %%
df = dd.read_csv("flights-larger.csv", assume_missing=True)

# %%
df.head(5)
# Out:
#     mon   dom  dow carrier  flight  org    mile  depart  duration  delay
# 0  10.0  10.0  1.0      OO  5836.0  ORD   157.0    8.18      51.0   27.0
# 1   1.0   4.0  1.0      OO  5866.0  ORD   466.0   15.50     102.0    NaN
# 2  11.0  22.0  1.0      OO  6016.0  ORD   738.0    7.17     127.0  -19.0
# 3   2.0  14.0  5.0      B6   199.0  JFK  2248.0   21.17     365.0   60.0
# 4   5.0  25.0  3.0      WN  1675.0  SJC   386.0   12.92      85.0   22.0

# %%
df.compute()
# Out:
#          mon   dom  dow carrier  flight  org    mile  depart  duration  delay
# 0       10.0  10.0  1.0      OO  5836.0  ORD   157.0    8.18      51.0   27.0
# 1        1.0   4.0  1.0      OO  5866.0  ORD   466.0   15.50     102.0    NaN
# 2       11.0  22.0  1.0      OO  6016.0  ORD   738.0    7.17     127.0  -19.0
# 3        2.0  14.0  5.0      B6   199.0  JFK  2248.0   21.17     365.0   60.0
# 4        5.0  25.0  3.0      WN  1675.0  SJC   386.0   12.92      85.0   22.0
# ...      ...   ...  ...     ...     ...  ...     ...     ...       ...    ...
# 274995   4.0  31.0  6.0      UA   259.0  ORD   888.0   16.75     154.0   46.0
# 274996   3.0  14.0  1.0      UA   119.0  SFO   337.0   16.20      84.0   33.0
# 274997  10.0   4.0  2.0      AA   716.0  ORD  1005.0    7.00     155.0   -6.0
# 274998   9.0  27.0  1.0      B6   128.0  JFK   267.0   22.50      86.0  -19.0
# 274999   6.0  15.0  2.0      OH  5552.0  JFK   301.0    9.08     105.0  -15.0
#
# [275000 rows x 10 columns]

# %% [raw]
# Data columns:
#
# mon — month (int between 1 and 12)
#
# dom — day of month (int between 1 and 31)
#
# dow — day of week (int; 1 = Monday and 7 = Sunday)
#
# org — origin airport (str; IATA code)
#
# mile — distance (int; miles)
#
# carrier — carrier (str; IATA code)
#
# depart — departure time (int; decimal hour)
#
# duration — expected duration (int; minutes)
#
# delay — delay (int; minutes)
#
# (IATA -> International Air Transport Association)

# %%
df.shape
# Out:
# (Delayed('int-f7802354-b515-49f9-8c99-ef7d07c1eec9'), 10)

# %% [raw]
# Basic data exploration
# Exploring basic info like:
#
# How many records?
# Which datatypes?
# missing values etc.

# %%
df.dtypes
# Out:
# mon         float64
# dom         float64
# dow         float64
# carrier      object
# flight      float64
# org          object
# mile        float64
# depart      float64
# duration    float64
# delay       float64
# dtype: object

# %%
df.isnull().compute().sum()
# Out:
# mon             0
# dom             0
# dow             0
# carrier         0
# flight          0
# org             0
# mile            0
# depart          0
# duration        0
# delay       16711
# dtype: int64

# %%
#so only in delay we have around 16000 null values. so that dos not impact more.

# %%
# data preprocessiong for our model training.

#step-1 
#we are just predecting delay time taken from origin aripot to carrier..

#drop flight column its unmwanted.

df = df.drop(["flight"], axis=1)

# %%
df.compute()
# Out:
#          mon   dom  dow carrier  org    mile  depart  duration  delay
# 0       10.0  10.0  1.0      OO  ORD   157.0    8.18      51.0   27.0
# 1        1.0   4.0  1.0      OO  ORD   466.0   15.50     102.0    NaN
# 2       11.0  22.0  1.0      OO  ORD   738.0    7.17     127.0  -19.0
# 3        2.0  14.0  5.0      B6  JFK  2248.0   21.17     365.0   60.0
# 4        5.0  25.0  3.0      WN  SJC   386.0   12.92      85.0   22.0
# ...      ...   ...  ...     ...  ...     ...     ...       ...    ...
# 274995   4.0  31.0  6.0      UA  ORD   888.0   16.75     154.0   46.0
# 274996   3.0  14.0  1.0      UA  SFO   337.0   16.20      84.0   33.0
# 274997  10.0   4.0  2.0      AA  ORD  1005.0    7.00     155.0   -6.0
# 274998   9.0  27.0  1.0      B6  JFK   267.0   22.50      86.0  -19.0
# 274999   6.0  15.0  2.0      OH  JFK   301.0    9.08     105.0  -15.0
#
# [275000 rows x 9 columns]

# %%
df =  df.dropna()

# %%
df.compute()
# Out:
#          mon   dom  dow carrier  org    mile  depart  duration  delay
# 0       10.0  10.0  1.0      OO  ORD   157.0    8.18      51.0   27.0
# 2       11.0  22.0  1.0      OO  ORD   738.0    7.17     127.0  -19.0
# 3        2.0  14.0  5.0      B6  JFK  2248.0   21.17     365.0   60.0
# 4        5.0  25.0  3.0      WN  SJC   386.0   12.92      85.0   22.0
# 5        3.0  28.0  1.0      B6  LGA  1076.0   13.33     182.0   70.0
# ...      ...   ...  ...     ...  ...     ...     ...       ...    ...
# 274995   4.0  31.0  6.0      UA  ORD   888.0   16.75     154.0   46.0
# 274996   3.0  14.0  1.0      UA  SFO   337.0   16.20      84.0   33.0
# 274997  10.0   4.0  2.0      AA  ORD  1005.0    7.00     155.0   -6.0
# 274998   9.0  27.0  1.0      B6  JFK   267.0   22.50      86.0  -19.0
# 274999   6.0  15.0  2.0      OH  JFK   301.0    9.08     105.0  -15.0
#
# [258289 rows x 9 columns]

# %%
df1 = df

# %%
# # Convert 'mile' to 'km' and drop 'mile'
# flights_km = df1.assign(km=round(df1.mile * 1.60934)).drop(columns='mile')

# %%
# Convert miles to km and store the result in a new column 'km'
df1['km'] = df1['mile'].mul(1.60934)

# %%
df1.head(5)
# Out:
#     mon   dom  dow carrier  org    mile  depart  duration  delay          km
# 0  10.0  10.0  1.0      OO  ORD   157.0    8.18      51.0   27.0   252.66638
# 2  11.0  22.0  1.0      OO  ORD   738.0    7.17     127.0  -19.0  1187.69292
# 3   2.0  14.0  5.0      B6  JFK  2248.0   21.17     365.0   60.0  3617.79632
# 4   5.0  25.0  3.0      WN  SJC   386.0   12.92      85.0   22.0   621.20524
# 5   3.0  28.0  1.0      B6  LGA  1076.0   13.33     182.0   70.0  1731.64984

# %%
df1.drop(['mile'], axis=1).compute()
# Out:
#          mon   dom  dow carrier  org  depart  duration  delay          km
# 0       10.0  10.0  1.0      OO  ORD    8.18      51.0   27.0   252.66638
# 2       11.0  22.0  1.0      OO  ORD    7.17     127.0  -19.0  1187.69292
# 3        2.0  14.0  5.0      B6  JFK   21.17     365.0   60.0  3617.79632
# 4        5.0  25.0  3.0      WN  SJC   12.92      85.0   22.0   621.20524
# 5        3.0  28.0  1.0      B6  LGA   13.33     182.0   70.0  1731.64984
# ...      ...   ...  ...     ...  ...     ...       ...    ...         ...
# 274995   4.0  31.0  6.0      UA  ORD   16.75     154.0   46.0  1429.09392
# 274996   3.0  14.0  1.0      UA  SFO   16.20      84.0   33.0   542.34758
# 274997  10.0   4.0  2.0      AA  ORD    7.00     155.0   -6.0  1617.38670
# 274998   9.0  27.0  1.0      B6  JFK   22.50      86.0  -19.0   429.69378
# 274999   6.0  15.0  2.0      OH  JFK    9.08     105.0  -15.0   484.41134
#
# [258289 rows x 9 columns]

# %%
# Create 'label' column indicating whether a flight is delayed or not
df1['label'] = (df1['delay'].ge(15)).astype('int')

# %%
df1.compute()
# Out:
#          mon   dom  dow carrier  org    mile  depart  duration  delay  \
# 0       10.0  10.0  1.0      OO  ORD   157.0    8.18      51.0   27.0
# 2       11.0  22.0  1.0      OO  ORD   738.0    7.17     127.0  -19.0
# 3        2.0  14.0  5.0      B6  JFK  2248.0   21.17     365.0   60.0
# 4        5.0  25.0  3.0      WN  SJC   386.0   12.92      85.0   22.0
# 5        3.0  28.0  1.0      B6  LGA  1076.0   13.33     182.0   70.0
# ...      ...   ...  ...     ...  ...     ...     ...       ...    ...
# 274995   4.0  31.0  6.0      UA  ORD   888.0   16.75     154.0   46.0
# 274996   3.0  14.0  1.0      UA  SFO   337.0   16.20      84.0   33.0
# 274997  10.0   4.0  2.0      AA  ORD  1005.0    7.00     155.0   -6.0
# 274998   9.0  27.0  1.0      B6  JFK   267.0   22.50      86.0  -19.0
# 274999   6.0  15.0  2.0      OH  JFK   301.0    9.08     105.0  -15.0
#
#                 km  label
# 0        252.66638      1
# 2       1187.69292      0
# 3       3617.79632      1
# 4        621.20524      1
# 5       1731.64984      1
# ...            ...    ...
# 274995  1429.09392      1
# 274996   542.34758      1
# 274997  1617.38670      0
# 274998   429.69378      0
# 274999   484.41134      0
#
# [258289 rows x 11 columns]

# %%
df1.head()
# Out:
#     mon   dom  dow carrier  org    mile  depart  duration  delay          km  \
# 0  10.0  10.0  1.0      OO  ORD   157.0    8.18      51.0   27.0   252.66638
# 2  11.0  22.0  1.0      OO  ORD   738.0    7.17     127.0  -19.0  1187.69292
# 3   2.0  14.0  5.0      B6  JFK  2248.0   21.17     365.0   60.0  3617.79632
# 4   5.0  25.0  3.0      WN  SJC   386.0   12.92      85.0   22.0   621.20524
# 5   3.0  28.0  1.0      B6  LGA  1076.0   13.33     182.0   70.0  1731.64984
#
#    label
# 0      1
# 2      0
# 3      1
# 4      1
# 5      1

# %%
data = df1.categorize(columns=['carrier', 'org'])
data.head()
# Out:
#     mon   dom  dow carrier  org    mile  depart  duration  delay          km  \
# 0  10.0  10.0  1.0      OO  ORD   157.0    8.18      51.0   27.0   252.66638
# 2  11.0  22.0  1.0      OO  ORD   738.0    7.17     127.0  -19.0  1187.69292
# 3   2.0  14.0  5.0      B6  JFK  2248.0   21.17     365.0   60.0  3617.79632
# 4   5.0  25.0  3.0      WN  SJC   386.0   12.92      85.0   22.0   621.20524
# 5   3.0  28.0  1.0      B6  LGA  1076.0   13.33     182.0   70.0  1731.64984
#
#    label
# 0      1
# 2      0
# 3      1
# 4      1
# 5      1

# %%
df2 = data.compute()

# %%
df2 = df2[['carrier', 'org']]
df2.head()
# Out:
#   carrier  org
# 0      OO  ORD
# 2      OO  ORD
# 3      B6  JFK
# 4      WN  SJC
# 5      B6  LGA

# %%
from dask_ml.preprocessing import OrdinalEncoder

# %%
enc = OrdinalEncoder()
trn = enc.fit_transform(df2)

# %%
trn.head()
# Out:
#    carrier  org
# 0        5    3
# 2        5    3
# 3        2    0
# 4        8    5
# 5        2    1

# %%
#drop the encoded columns and merge encoded columns new
df1 = df1.drop(["carrier","org"], axis=1)

# %%
# Merge trn DataFrame to df2 on a common column 'common_col'
df3 = df1.merge(trn)

# %%
df3.head()
# Out:
#     mon   dom  dow    mile  depart  duration  delay          km  label  \
# 0  10.0  10.0  1.0   157.0    8.18      51.0   27.0   252.66638      1
# 2  11.0  22.0  1.0   738.0    7.17     127.0  -19.0  1187.69292      0
# 3   2.0  14.0  5.0  2248.0   21.17     365.0   60.0  3617.79632      1
# 4   5.0  25.0  3.0   386.0   12.92      85.0   22.0   621.20524      1
# 5   3.0  28.0  1.0  1076.0   13.33     182.0   70.0  1731.64984      1
#
#    carrier  org
# 0        5    3
# 2        5    3
# 3        2    0
# 4        8    5
# 5        2    1

# %%
# # Iterate through each categorical column and perform ordinal encoding
# for col in cat_cols:
#     # Convert the series column to a dataframe column
#     df_col = df1[col].to_frame()
    
#     # Encode the categorical column
#     encoder = pp.OrdinalEncoder()
#     df_encoded = encoder.fit_transform(df1[[col]])

# %%
df3.compute()
# Out:
#          mon   dom  dow    mile  depart  duration  delay          km  label  \
# 0       10.0  10.0  1.0   157.0    8.18      51.0   27.0   252.66638      1
# 2       11.0  22.0  1.0   738.0    7.17     127.0  -19.0  1187.69292      0
# 3        2.0  14.0  5.0  2248.0   21.17     365.0   60.0  3617.79632      1
# 4        5.0  25.0  3.0   386.0   12.92      85.0   22.0   621.20524      1
# 5        3.0  28.0  1.0  1076.0   13.33     182.0   70.0  1731.64984      1
# ...      ...   ...  ...     ...     ...       ...    ...         ...    ...
# 274995   4.0  31.0  6.0   888.0   16.75     154.0   46.0  1429.09392      1
# 274996   3.0  14.0  1.0   337.0   16.20      84.0   33.0   542.34758      1
# 274997  10.0   4.0  2.0  1005.0    7.00     155.0   -6.0  1617.38670      0
# 274998   9.0  27.0  1.0   267.0   22.50      86.0  -19.0   429.69378      0
# 274999   6.0  15.0  2.0   301.0    9.08     105.0  -15.0   484.41134      0
#
#         carrier  org
# 0             5    3
# 2             5    3
# 3             2    0
# 4             8    5
# 5             2    1
# ...         ...  ...
# 274995        6    3
# 274996        6    4
# 274997        0    3
# 274998        2    0
# 274999        4    0
#
# [258289 rows x 11 columns]

# %%
# import dask_ml.preprocessing as dpp

# # Create a list of column names to include in the feature vector
# input_cols = ['mon', 'dom', 'dow', 'carrier', 'org', 'km', 'depart', 'duration']

# # Create a Dask VectorAssembler object
# assembler = dpp.VectorAssembler(input_cols, output_col='features')

# %%
# df4 = assembler.transform(df3)

# %%
import dask_ml.datasets as dmd
x = df3[['mon', 'dom', 'dow', 'carrier', 'org', 'km', 'depart', 'duration']]
y = df3['delay']

# Load the data as a Dask array
X, y = dmd.make_classification(n_samples=100000, n_features=20, chunks=1000)
# Out:
# C:\Users\123sa\anaconda3\lib\site-packages\dask\base.py:1368: UserWarning: Running on a single-machine scheduler when a distributed client is active might lead to unexpected results.
#   warnings.warn(

# %%
import dask_ml.model_selection as dm
# Split the data into training and testing sets
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = dm.train_test_split(X, y, test_size=0.2)

# %%
X_train
# Out:
# dask.array<concatenate, shape=(80000, 20), dtype=float64, chunksize=(800, 20), chunktype=numpy.ndarray>

# %%
y_train
# Out:
# dask.array<concatenate, shape=(80000,), dtype=int32, chunksize=(800,), chunktype=numpy.ndarray>

# %%
import dask.dataframe as dd
import dask_ml.model_selection as dms
from dask_ml.linear_model import LogisticRegression


# Create a LogisticRegression object
clf = LogisticRegression()

# Fit the classifier on the training data
clf.fit(X_train, y_train)

# Predict the target variable for the testing data
y_pred = clf.predict(X_test)
# Out:
# 2023-05-07 11:13:06,878 - tornado.application - ERROR - Uncaught exception GET /status/ws (192.168.0.100)
# HTTPServerRequest(protocol='http', host='192.168.0.100:8787', method='GET', uri='/status/ws', version='HTTP/1.1', remote_ip='192.168.0.100')
# Traceback (most recent call last):
#   File "C:\Users\123sa\anaconda3\lib\site-packages\tornado\websocket.py", line 954, in _accept_connection
#     open_result = handler.open(*handler.open_args, **handler.open_kwargs)
#   File "C:\Users\123sa\anaconda3\lib\site-packages\tornado\web.py", line 3173, in wrapper
#     return method(self, *args, **kwargs)
#   File "C:\Users\123sa\anaconda3\lib\site-packages\bokeh\server\views\ws.py", line 149, in open
#     raise ProtocolError("Token is expired.")
# bokeh.protocol.exceptions.ProtocolError: Token is expired.
# 2023-05-07 11:14:53,845 - tornado.application - ERROR - Exception in callback <bound method BokehTornado._keep_alive of <bokeh.server.tornado.BokehTornado object at 0x00000233013E6950>>
# Traceback (most recent call last):
#   File "C:\Users\123sa\anaconda3\lib\site-packages\tornado\ioloop.py", line 905, in _run
#     return self.callback()
#   File "C:\Users\123sa\anaconda3\lib\site-packages\bokeh\server\tornado.py", line 760, in _keep_alive
#     c.send_ping()
#   File "C:\Users\123sa\anaconda3\lib\site-packages\bokeh\server\connection.py", line 93, in send_ping
#     self._socket.ping(str(self._ping_count).encode("utf-8"))
#   File "C:\Users\123sa\anaconda3\lib\site-packages\tornado\websocket.py", line 445, in ping
#     raise WebSocketClosedError()
# tornado.websocket.WebSocketClosedError
# 2023-05-07 11:14:56,342 - tornado.application - ERROR - Uncaught exception GET /status/ws (192.168.0.100)
# HTTPServerRequest(protocol='http', host='192.168.0.100:8787', method='GET', uri='/status/ws', version='HTTP/1.1', remote_ip='192.168.0.100')
# Traceback (most recent call last):
#   File "C:\Users\123sa\anaconda3\lib\site-packages\tornado\websocket.py", line 954, in _accept_connection
#     open_result = handler.open(*handler.open_args, **handler.open_kwargs)
#   File "C:\Users\123sa\anaconda3\lib\site-packages\tornado\web.py", line 3173, in wrapper
#     return method(self, *args, **kwargs)
#   File "C:\Users\123sa\anaconda3\lib\site-packages\bokeh\server\views\ws.py", line 149, in open
#     raise ProtocolError("Token is expired.")
# bokeh.protocol.exceptions.ProtocolError: Token is expired.
# 2023-05-07 11:17:05,346 - tornado.application - ERROR - Exception in callback <bound method BokehTornado._keep_alive of <bokeh.server.tornado.BokehTornado object at 0x00000233013E6950>>
# Traceback (most recent call last):
#   File "C:\Users\123sa\anaconda3\lib\site-packages\tornado\ioloop.py", line 905, in _run
#     return self.callback()
#   File "C:\Users\123sa\anaconda3\lib\site-packages\bokeh\server\tornado.py", line 760, in _keep_alive
#     c.send_ping()
#   File "C:\Users\123sa\anaconda3\lib\site-packages\bokeh\server\connection.py", line 93, in send_ping
#     self._socket.ping(str(self._ping_count).encode("utf-8"))
#   File "C:\Users\123sa\anaconda3\lib\site-packages\tornado\websocket.py", line 445, in ping
#     raise WebSocketClosedError()
# tornado.websocket.WebSocketClosedError
# 2023-05-07 11:17:05,828 - tornado.application - ERROR - Exception in callback <bound method BokehTornado._keep_alive of <bokeh.server.tornado.BokehTornado object at 0x00000233013E6950>>
# Traceback (most recent call last):
#   File "C:\Users\123sa\anaconda3\lib\site-packages\tornado\ioloop.py", line 905, in _run
#     return self.callback()
#   File "C:\Users\123sa\anaconda3\lib\site-packages\bokeh\server\tornado.py", line 760, in _keep_alive
#     c.send_ping()
#   File "C:\Users\123sa\anaconda3\lib\site-packages\bokeh\server\connection.py", line 93, in send_ping
#     self._socket.ping(str(self._ping_count).encode("utf-8"))
#   File "C:\Users\123sa\anaconda3\lib\site-packages\tornado\websocket.py", line 445, in ping
#     raise WebSocketClosedError()
# tornado.websocket.WebSocketClosedError

# %%
# Compute the accuracy of the model
accuracy = (y_pred == y_test).sum() / len(y_test)
accuracy = accuracy.compute()
# Print the accuracy
print(f"Accuracy: {accuracy}")
# Out:
# Accuracy: 0.7046
